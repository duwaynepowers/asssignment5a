# %%
import zipfile

with zipfile.ZipFile('/content/archive.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %% [markdown]
# I had to download the file as a zip so this unzipped it so I could use it as a CSV

# %%
from google.colab import userdata, drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# This connected Google Drive to Colab

# %%
import pandas as pd

df = pd.read_csv('/content/StudentsPerformance.csv')

print("File loaded!")
print(df.head())
# Out:
# File loaded!
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# This loaded the CSV file into pandas and shows the first few rows

# %%
print(df.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# This showed the summary of the stats of student scores

# %%
print("Math avg:", df['math score'].mean())
print("Reading avg:", df['reading score'].mean())
print("Writing avg:", df['writing score'].mean())
# Out:
# Math avg: 66.089
# Reading avg: 69.169
# Writing avg: 68.054

# %% [markdown]
# This calculated the average scroes for each class

# %%
print("Observations:")
print("- Reading/Writing slightly higher than Math")
print("- Scores vary a lot between students")
# Out:
# Observations:
# - Reading/Writing slightly higher than Math
# - Scores vary a lot between students

# %% [markdown]
# This printed the simple observations about the dataset

# %% [markdown]
# I used a new dataset and analyzed it using pandas. I loaded the data, viewed the first few rows, and used summary stats to understand it. I originally tried using the AI agents like tast 1, but due to API issues, I had to simplify it using python. Each variation of model would just rate limit so I simplified it like the directions said until it worked.
